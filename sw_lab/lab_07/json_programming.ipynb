# %% [markdown]
# # Denison CS181/DA210 SW Lab #7 - Step 1
#
# Before you get your checkpoints, make sure everything runs as expected. This is a combination of **restarting the kernel** and then **running all cells**.
#
# Make sure you fill in any place that says `# YOUR CODE HERE` or "YOUR ANSWER HERE".

# %% [markdown]
# ---

# %%
import os
import os.path
import json
import pandas as pd

datadir = "publicdata"

# %% [markdown]
# ---
#
# ## `json` module operations
#
# Recall the following operations provided by the `json` module in Python:
#
# Function                |  Description
# ------------------------|----------------------------------------------------
# `json.load(file)`       | Read and return the JSON-formatted data structure from the file object `file`.
# `json.dump(data, file)` | Write the data structure `data` to the file object `file` in JSON text format (returns `None`).
# `json.loads(s)`         | Using the JSON-formatted string given by `s`, interpret and construct and return the corresponding data structure.
# `json.dumps(data)`      | Translate the data structure `data` into a JSON-formatted string and return the string.
#
# Note that, when we `dump()` or `dumps()`, we are **converting** from an in-memory data structure that consists of dictionaries, lists, strings, and numbers (that one can "do math" on), into what is fundamentally a **text string**, either referenced by a string variable, or that is now the text contents of a text file in the file system, which could be opened with an editor independently of anything Python'esque.
#
# When we `load()` or `loads()`, we are going the other direction, and are converting from a string or from the contents of a text file in the file system, and are building an in-memory data structure that we can then traverse and compute with.

# %% [markdown]
# ---
#
# ## Part A: Writing to JSON
#
# Typical steps when we want to **create** a file with the JSON text representation of a data structure from our Python program (to be able to send to another scientist, much like we might build a 2D structure and then want to send a CSV file).
#
# 1. Create the data structure, making sure it is limited to dictionaries, lists, strings, integers, and floating point numbers in a single data structure.  Call this `data`.
# 2. Using the built-in Python function `open`, create and open a file for **writing**, specifying the path and name for the desired file.  We can call the file object `file`.
# 3. From the `json` module, invoke the `dump()` function, passing it `data` and `file`.
# 4. Close `file` (this is done for you if you used `with` to open the file).

# %% [markdown]
# ---
#
# **Q1:** Use the four step process given above to write to a JSON-formatted file.
#
# Create a Python data structure consisting of a list of dictionaries representation of the following table, where student names are strings, GPAs are floating point numbers, and (class) years are integers.
#
# student | gpa | year
# --------|-----|-------
# Jane    | 3.75 | 3
# Bill    | 2.85 | 2
# Fred    | 3.5  | 3
# Mary    | 3.25 | 1
#
# Call the in-memory data structure `LoD`.  For this exercise, the desired destination file should be in the current directory and will be named `students.json`.

# %%
# Make sure you don't already have a file named students.json
path = os.path.join(".", "students.json")
if os.path.isfile(path):
    os.remove(path)

LoD=[{'student':'Jane','gpa':3.75,'year':3},{'student':'Bill','gpa':2.85,'year':2},{'student':'Fred','gpa':3.5,'year':3},{'student':'Mary','gpa':3.25,'year':1}]
with open(path,'w') as f:
    json.dump(LoD,f)

# %%
# Testing cell
assert os.path.isfile(path)
with open(path, "r") as F2:
    LoD2 = json.load(F2)
assert isinstance(LoD2, list)
assert len(LoD2) == 4
assert isinstance(LoD2[0], dict)
assert len(LoD2[0]) == 3
assert 'student' in LoD2[0]
assert 'gpa' in LoD2[0]
assert 'year' in LoD2[0]
assert isinstance(LoD[0]['gpa'], float)
assert isinstance(LoD[0]['year'], int)
assert LoD[0]['gpa'] == 3.75
assert LoD[0]['year'] == 3

# %% [markdown]
# ---
#
# ## Part B: Reading from JSON
#
# In the data directory is a text file named `eu_covid.json`.  Right click and select `Editor` to open with a simple text editor.  Be patient, as it is a **large** file.  Then use the following cell to print the first 30 lines of the file.

# %%
path = os.path.join(datadir, "eu_covid.json")
with open(path, 'r') as covid_file:
    for i in range(30):
        line = covid_file.readline()
        print(line, end='')
# Out:
# {
#    "records" : [
#       {
#          "dateRep" : "21/09/2020",
#          "day" : "21",
#          "month" : "09",
#          "year" : "2020",
#          "cases" : 0,
#          "deaths" : 0,
#          "countriesAndTerritories" : "Afghanistan",
#          "geoId" : "AF",
#          "countryterritoryCode" : "AFG",
#          "popData2019" : 38041757,
#          "continentExp" : "Asia",
#          "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000" : "1.69813397"
#       },
#       {
#          "dateRep" : "20/09/2020",
#          "day" : "20",
#          "month" : "09",
#          "year" : "2020",
#          "cases" : 125,
#          "deaths" : 4,
#          "countriesAndTerritories" : "Afghanistan",
#          "geoId" : "AF",
#          "countryterritoryCode" : "AFG",
#          "popData2019" : 38041757,
#          "continentExp" : "Asia",
#          "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000" : "1.89265706"
#       },

# %% [markdown]
# **Q2:** To be able to process tree-structured data, you first must **understand** the structure before you attempt to process it.  The next couple of sub-questions begin that process based on **inspection** of the text file, and before we convert it into an in-memory data structure.
#
# **A:** What is the JSON data type for the structure at the root of the tree?
#
# **B:** What is the JSON data type for the **value** that the top-level child **maps to**.
#
# **C.** Within the data type you answered for **B**, what is the JSON data type for the elements at this next level of the tree?

# %% [markdown]
# > You've reached the first checkpoint in the lab.  Make sure to have it signed off by the instructor or TA.
# >
# > Checkpoint 1: What are your answers to sub-questions A-C above?

# %% [markdown]
# **Q3:** Create a variable for the path to the `eu_covid.json` JSON file and then `open()` and `load()` from the text file into an in-memory data structure in Python referred to by variable `covid_data`.

# %%
with open(os.path.join(datadir,'eu_covid.json')) as f:
    covid_data=json.load(f)
covid_data
# Out:
# {'records': [{'dateRep': '21/09/2020',
#    'day': '21',
#    'month': '09',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.69813397'},
#   {'dateRep': '20/09/2020',
#    'day': '20',
#    'month': '09',
#    'year': '2020',
#    'cases': 125,
#    'deaths': 4,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.89265706'},
#   {'dateRep': '19/09/2020',
#    'day': '19',
#    'month': '09',
#    'year': '2020',
#    'cases': 47,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.61664457'},
#   {'dateRep': '18/09/2020',
#    'day': '18',
#    'month': '09',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.53515517'},
#   {'dateRep': '17/09/2020',
#    'day': '17',
#    'month': '09',
#    'year': '2020',
#    'cases': 17,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.65344624'},
#   {'dateRep': '16/09/2020',
#    'day': '16',
#    'month': '09',
#    'year': '2020',
#    'cases': 40,
#    'deaths': 10,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.70864874'},
#   {'dateRep': '15/09/2020',
#    'day': '15',
#    'month': '09',
#    'year': '2020',
#    'cases': 99,
#    'deaths': 6,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.62715933'},
#   {'dateRep': '14/09/2020',
#    'day': '14',
#    'month': '09',
#    'year': '2020',
#    'cases': 75,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.45629446'},
#   {'dateRep': '13/09/2020',
#    'day': '13',
#    'month': '09',
#    'year': '2020',
#    'cases': 35,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.3090878'},
#   {'dateRep': '12/09/2020',
#    'day': '12',
#    'month': '09',
#    'year': '2020',
#    'cases': 34,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.22496971'},
#   {'dateRep': '11/09/2020',
#    'day': '11',
#    'month': '09',
#    'year': '2020',
#    'cases': 28,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.16450983'},
#   {'dateRep': '10/09/2020',
#    'day': '10',
#    'month': '09',
#    'year': '2020',
#    'cases': 24,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.09879257'},
#   {'dateRep': '09/09/2020',
#    'day': '09',
#    'month': '09',
#    'year': '2020',
#    'cases': 26,
#    'deaths': 3,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.18028197'},
#   {'dateRep': '08/09/2020',
#    'day': '08',
#    'month': '09',
#    'year': '2020',
#    'cases': 96,
#    'deaths': 3,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.11456471'},
#   {'dateRep': '07/09/2020',
#    'day': '07',
#    'month': '09',
#    'year': '2020',
#    'cases': 74,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.04884745'},
#   {'dateRep': '06/09/2020',
#    'day': '06',
#    'month': '09',
#    'year': '2020',
#    'cases': 20,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.85432437'},
#   {'dateRep': '05/09/2020',
#    'day': '05',
#    'month': '09',
#    'year': '2020',
#    'cases': 16,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.07776305'},
#   {'dateRep': '04/09/2020',
#    'day': '04',
#    'month': '09',
#    'year': '2020',
#    'cases': 45,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.13559424'},
#   {'dateRep': '03/09/2020',
#    'day': '03',
#    'month': '09',
#    'year': '2020',
#    'cases': 38,
#    'deaths': 3,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.27228614'},
#   {'dateRep': '02/09/2020',
#    'day': '02',
#    'month': '09',
#    'year': '2020',
#    'cases': 9,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.59298636'},
#   {'dateRep': '01/09/2020',
#    'day': '01',
#    'month': '09',
#    'year': '2020',
#    'cases': 34,
#    'deaths': 4,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.56932815'},
#   {'dateRep': '31/08/2020',
#    'day': '31',
#    'month': '08',
#    'year': '2020',
#    'cases': 19,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.48783875'},
#   {'dateRep': '30/08/2020',
#    'day': '30',
#    'month': '08',
#    'year': '2020',
#    'cases': 3,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.55618469'},
#   {'dateRep': '29/08/2020',
#    'day': '29',
#    'month': '08',
#    'year': '2020',
#    'cases': 11,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.86374147'},
#   {'dateRep': '28/08/2020',
#    'day': '28',
#    'month': '08',
#    'year': '2020',
#    'cases': 3,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.85322671'},
#   {'dateRep': '27/08/2020',
#    'day': '27',
#    'month': '08',
#    'year': '2020',
#    'cases': 55,
#    'deaths': 4,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.05300717'},
#   {'dateRep': '26/08/2020',
#    'day': '26',
#    'month': '08',
#    'year': '2020',
#    'cases': 1,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.10820967'},
#   {'dateRep': '25/08/2020',
#    'day': '25',
#    'month': '08',
#    'year': '2020',
#    'cases': 71,
#    'deaths': 10,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.67074941'},
#   {'dateRep': '24/08/2020',
#    'day': '24',
#    'month': '08',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.48411239'},
#   {'dateRep': '23/08/2020',
#    'day': '23',
#    'month': '08',
#    'year': '2020',
#    'cases': 105,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.48411239'},
#   {'dateRep': '22/08/2020',
#    'day': '22',
#    'month': '08',
#    'year': '2020',
#    'cases': 38,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.31061883'},
#   {'dateRep': '21/08/2020',
#    'day': '21',
#    'month': '08',
#    'year': '2020',
#    'cases': 97,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.41576644'},
#   {'dateRep': '20/08/2020',
#    'day': '20',
#    'month': '08',
#    'year': '2020',
#    'cases': 160,
#    'deaths': 8,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.26855978'},
#   {'dateRep': '19/08/2020',
#    'day': '19',
#    'month': '08',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.02409158'},
#   {'dateRep': '18/08/2020',
#    'day': '18',
#    'month': '08',
#    'year': '2020',
#    'cases': 3,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.23964419'},
#   {'dateRep': '17/08/2020',
#    'day': '17',
#    'month': '08',
#    'year': '2020',
#    'cases': 45,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.32901966'},
#   {'dateRep': '16/08/2020',
#    'day': '16',
#    'month': '08',
#    'year': '2020',
#    'cases': 120,
#    'deaths': 7,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.21072859'},
#   {'dateRep': '15/08/2020',
#    'day': '15',
#    'month': '08',
#    'year': '2020',
#    'cases': 7,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.89528575'},
#   {'dateRep': '14/08/2020',
#    'day': '14',
#    'month': '08',
#    'year': '2020',
#    'cases': 79,
#    'deaths': 9,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.3185049'},
#   {'dateRep': '13/08/2020',
#    'day': '13',
#    'month': '08',
#    'year': '2020',
#    'cases': 76,
#    'deaths': 10,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.29747538'},
#   {'dateRep': '12/08/2020',
#    'day': '12',
#    'month': '08',
#    'year': '2020',
#    'cases': 215,
#    'deaths': 32,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.09769491'},
#   {'dateRep': '11/08/2020',
#    'day': '11',
#    'month': '08',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.80328159'},
#   {'dateRep': '10/08/2020',
#    'day': '10',
#    'month': '08',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.07929408'},
#   {'dateRep': '09/08/2020',
#    'day': '09',
#    'month': '08',
#    'year': '2020',
#    'cases': 39,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.35793526'},
#   {'dateRep': '08/08/2020',
#    'day': '08',
#    'month': '08',
#    'year': '2020',
#    'cases': 78,
#    'deaths': 9,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.57348786'},
#   {'dateRep': '07/08/2020',
#    'day': '07',
#    'month': '08',
#    'year': '2020',
#    'cases': 41,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.65234858'},
#   {'dateRep': '06/08/2020',
#    'day': '06',
#    'month': '08',
#    'year': '2020',
#    'cases': 67,
#    'deaths': 4,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.57874525'},
#   {'dateRep': '05/08/2020',
#    'day': '05',
#    'month': '08',
#    'year': '2020',
#    'cases': 82,
#    'deaths': 6,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.89681678'},
#   {'dateRep': '04/08/2020',
#    'day': '04',
#    'month': '08',
#    'year': '2020',
#    'cases': 37,
#    'deaths': 4,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '2.97567749'},
#   {'dateRep': '03/08/2020',
#    'day': '03',
#    'month': '08',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '3.2464326'},
#   {'dateRep': '02/08/2020',
#    'day': '02',
#    'month': '08',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '3.70382472'},
#   {'dateRep': '01/08/2020',
#    'day': '01',
#    'month': '08',
#    'year': '2020',
#    'cases': 168,
#    'deaths': 12,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '3.73536901'},
#   {'dateRep': '31/07/2020',
#    'day': '31',
#    'month': '07',
#    'year': '2020',
#    'cases': 71,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '3.86943221'},
#   {'dateRep': '30/07/2020',
#    'day': '30',
#    'month': '07',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '3.88257567'},
#   {'dateRep': '29/07/2020',
#    'day': '29',
#    'month': '07',
#    'year': '2020',
#    'cases': 103,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '4.55026302'},
#   {'dateRep': '28/07/2020',
#    'day': '28',
#    'month': '07',
#    'year': '2020',
#    'cases': 105,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '5.02868466'},
#   {'dateRep': '27/07/2020',
#    'day': '27',
#    'month': '07',
#    'year': '2020',
#    'cases': 106,
#    'deaths': 10,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '4.76318694'},
#   {'dateRep': '26/07/2020',
#    'day': '26',
#    'month': '07',
#    'year': '2020',
#    'cases': 121,
#    'deaths': 13,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '4.48454576'},
#   {'dateRep': '25/07/2020',
#    'day': '25',
#    'month': '07',
#    'year': '2020',
#    'cases': 108,
#    'deaths': 35,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '4.38991291'},
#   {'dateRep': '24/07/2020',
#    'day': '24',
#    'month': '07',
#    'year': '2020',
#    'cases': 13,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '5.30995453'},
#   {'dateRep': '23/07/2020',
#    'day': '23',
#    'month': '07',
#    'year': '2020',
#    'cases': 188,
#    'deaths': 21,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '5.9460976'},
#   {'dateRep': '22/07/2020',
#    'day': '22',
#    'month': '07',
#    'year': '2020',
#    'cases': 112,
#    'deaths': 4,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '5.60699654'},
#   {'dateRep': '21/07/2020',
#    'day': '21',
#    'month': '07',
#    'year': '2020',
#    'cases': 140,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '5.8646082'},
#   {'dateRep': '20/07/2020',
#    'day': '20',
#    'month': '07',
#    'year': '2020',
#    'cases': 174,
#    'deaths': 17,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '6.63481448'},
#   {'dateRep': '19/07/2020',
#    'day': '19',
#    'month': '07',
#    'year': '2020',
#    'cases': 12,
#    'deaths': 17,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '6.91082696'},
#   {'dateRep': '18/07/2020',
#    'day': '18',
#    'month': '07',
#    'year': '2020',
#    'cases': 219,
#    'deaths': 32,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '7.79406692'},
#   {'dateRep': '17/07/2020',
#    'day': '17',
#    'month': '07',
#    'year': '2020',
#    'cases': 76,
#    'deaths': 21,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '8.01224823'},
#   {'dateRep': '16/07/2020',
#    'day': '16',
#    'month': '07',
#    'year': '2020',
#    'cases': 254,
#    'deaths': 49,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '8.30140416'},
#   {'dateRep': '15/07/2020',
#    'day': '15',
#    'month': '07',
#    'year': '2020',
#    'cases': 285,
#    'deaths': 33,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '8.47226904'},
#   {'dateRep': '14/07/2020',
#    'day': '14',
#    'month': '07',
#    'year': '2020',
#    'cases': 4,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '8.4564969'},
#   {'dateRep': '13/07/2020',
#    'day': '13',
#    'month': '07',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '9.15835722'},
#   {'dateRep': '12/07/2020',
#    'day': '12',
#    'month': '07',
#    'year': '2020',
#    'cases': 85,
#    'deaths': 16,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.08102754'},
#   {'dateRep': '11/07/2020',
#    'day': '11',
#    'month': '07',
#    'year': '2020',
#    'cases': 458,
#    'deaths': 37,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.29132277'},
#   {'dateRep': '10/07/2020',
#    'day': '10',
#    'month': '07',
#    'year': '2020',
#    'cases': 255,
#    'deaths': 20,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '9.81290112'},
#   {'dateRep': '09/07/2020',
#    'day': '09',
#    'month': '07',
#    'year': '2020',
#    'cases': 59,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.35178265'},
#   {'dateRep': '08/07/2020',
#    'day': '08',
#    'month': '07',
#    'year': '2020',
#    'cases': 210,
#    'deaths': 16,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.81180346'},
#   {'dateRep': '07/07/2020',
#    'day': '07',
#    'month': '07',
#    'year': '2020',
#    'cases': 433,
#    'deaths': 56,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '11.14827583'},
#   {'dateRep': '06/07/2020',
#    'day': '06',
#    'month': '07',
#    'year': '2020',
#    'cases': 279,
#    'deaths': 38,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.82494691'},
#   {'dateRep': '05/07/2020',
#    'day': '05',
#    'month': '07',
#    'year': '2020',
#    'cases': 348,
#    'deaths': 7,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '11.16667666'},
#   {'dateRep': '04/07/2020',
#    'day': '04',
#    'month': '07',
#    'year': '2020',
#    'cases': 302,
#    'deaths': 12,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '11.68715735'},
#   {'dateRep': '03/07/2020',
#    'day': '03',
#    'month': '07',
#    'year': '2020',
#    'cases': 186,
#    'deaths': 33,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '11.80281973'},
#   {'dateRep': '02/07/2020',
#    'day': '02',
#    'month': '07',
#    'year': '2020',
#    'cases': 319,
#    'deaths': 28,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '13.04356158'},
#   {'dateRep': '01/07/2020',
#    'day': '01',
#    'month': '07',
#    'year': '2020',
#    'cases': 279,
#    'deaths': 13,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '13.68759072'},
#   {'dateRep': '30/06/2020',
#    'day': '30',
#    'month': '06',
#    'year': '2020',
#    'cases': 271,
#    'deaths': 12,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '15.01245066'},
#   {'dateRep': '29/06/2020',
#    'day': '29',
#    'month': '06',
#    'year': '2020',
#    'cases': 351,
#    'deaths': 18,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '16.30050894'},
#   {'dateRep': '28/06/2020',
#    'day': '28',
#    'month': '06',
#    'year': '2020',
#    'cases': 165,
#    'deaths': 20,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '17.12328902'},
#   {'dateRep': '27/06/2020',
#    'day': '27',
#    'month': '06',
#    'year': '2020',
#    'cases': 276,
#    'deaths': 8,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '18.15110695'},
#   {'dateRep': '26/06/2020',
#    'day': '26',
#    'month': '06',
#    'year': '2020',
#    'cases': 460,
#    'deaths': 36,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '19.15000929'},
#   {'dateRep': '25/06/2020',
#    'day': '25',
#    'month': '06',
#    'year': '2020',
#    'cases': 234,
#    'deaths': 21,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '19.90444343'},
#   {'dateRep': '24/06/2020',
#    'day': '24',
#    'month': '06',
#    'year': '2020',
#    'cases': 338,
#    'deaths': 20,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '21.08735409'},
#   {'dateRep': '23/06/2020',
#    'day': '23',
#    'month': '06',
#    'year': '2020',
#    'cases': 310,
#    'deaths': 17,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '21.62360692'},
#   {'dateRep': '22/06/2020',
#    'day': '22',
#    'month': '06',
#    'year': '2020',
#    'cases': 409,
#    'deaths': 12,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '22.32020987'},
#   {'dateRep': '21/06/2020',
#    'day': '21',
#    'month': '06',
#    'year': '2020',
#    'cases': 546,
#    'deaths': 21,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '23.32436959'},
#   {'dateRep': '20/06/2020',
#    'day': '20',
#    'month': '06',
#    'year': '2020',
#    'cases': 346,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '23.41900244'},
#   {'dateRep': '19/06/2020',
#    'day': '19',
#    'month': '06',
#    'year': '2020',
#    'cases': 658,
#    'deaths': 42,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '24.91472726'},
#   {'dateRep': '18/06/2020',
#    'day': '18',
#    'month': '06',
#    'year': '2020',
#    'cases': 564,
#    'deaths': 13,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.25382831'},
#   {'dateRep': '17/06/2020',
#    'day': '17',
#    'month': '06',
#    'year': '2020',
#    'cases': 783,
#    'deaths': 13,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.76379424'},
#   {'dateRep': '16/06/2020',
#    'day': '16',
#    'month': '06',
#    'year': '2020',
#    'cases': 761,
#    'deaths': 7,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.70070567'},
#   {'dateRep': '15/06/2020',
#    'day': '15',
#    'month': '06',
#    'year': '2020',
#    'cases': 664,
#    'deaths': 20,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.13290856'},
#   {'dateRep': '14/06/2020',
#    'day': '14',
#    'month': '06',
#    'year': '2020',
#    'cases': 556,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.1749676'},
#   {'dateRep': '13/06/2020',
#    'day': '13',
#    'month': '06',
#    'year': '2020',
#    'cases': 656,
#    'deaths': 20,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.98986161'},
#   {'dateRep': '12/06/2020',
#    'day': '12',
#    'month': '06',
#    'year': '2020',
#    'cases': 747,
#    'deaths': 21,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.90311483'},
#   {'dateRep': '11/06/2020',
#    'day': '11',
#    'month': '06',
#    'year': '2020',
#    'cases': 684,
#    'deaths': 21,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.46412354'},
#   {'dateRep': '10/06/2020',
#    'day': '10',
#    'month': '06',
#    'year': '2020',
#    'cases': 542,
#    'deaths': 15,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.30903081'},
#   {'dateRep': '09/06/2020',
#    'day': '09',
#    'month': '06',
#    'year': '2020',
#    'cases': 575,
#    'deaths': 12,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.61395889'},
#   {'dateRep': '08/06/2020',
#    'day': '08',
#    'month': '06',
#    'year': '2020',
#    'cases': 791,
#    'deaths': 30,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.65601794'},
#   {'dateRep': '07/06/2020',
#    'day': '07',
#    'month': '06',
#    'year': '2020',
#    'cases': 582,
#    'deaths': 18,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.11187903'},
#   {'dateRep': '06/06/2020',
#    'day': '06',
#    'month': '06',
#    'year': '2020',
#    'cases': 915,
#    'deaths': 9,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '25.63761711'},
#   {'dateRep': '05/06/2020',
#    'day': '05',
#    'month': '06',
#    'year': '2020',
#    'cases': 787,
#    'deaths': 6,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '24.65185822'},
#   {'dateRep': '04/06/2020',
#    'day': '04',
#    'month': '06',
#    'year': '2020',
#    'cases': 758,
#    'deaths': 24,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '23.97891349'},
#   {'dateRep': '03/06/2020',
#    'day': '03',
#    'month': '06',
#    'year': '2020',
#    'cases': 759,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '23.27968185'},
#   {'dateRep': '02/06/2020',
#    'day': '02',
#    'month': '06',
#    'year': '2020',
#    'cases': 545,
#    'deaths': 8,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '22.81177497'},
#   {'dateRep': '01/06/2020',
#    'day': '01',
#    'month': '06',
#    'year': '2020',
#    'cases': 680,
#    'deaths': 8,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '22.45164439'},
#   {'dateRep': '31/05/2020',
#    'day': '31',
#    'month': '05',
#    'year': '2020',
#    'cases': 866,
#    'deaths': 3,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '21.35285181'},
#   {'dateRep': '30/05/2020',
#    'day': '30',
#    'month': '05',
#    'year': '2020',
#    'cases': 623,
#    'deaths': 11,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '19.07640596'},
#   {'dateRep': '29/05/2020',
#    'day': '29',
#    'month': '05',
#    'year': '2020',
#    'cases': 580,
#    'deaths': 8,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '20.23302972'},
#   {'dateRep': '28/05/2020',
#    'day': '28',
#    'month': '05',
#    'year': '2020',
#    'cases': 625,
#    'deaths': 7,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '19.00543132'},
#   {'dateRep': '27/05/2020',
#    'day': '27',
#    'month': '05',
#    'year': '2020',
#    'cases': 658,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '18.04333065'},
#   {'dateRep': '26/05/2020',
#    'day': '26',
#    'month': '05',
#    'year': '2020',
#    'cases': 591,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '17.04968569'},
#   {'dateRep': '25/05/2020',
#    'day': '25',
#    'month': '05',
#    'year': '2020',
#    'cases': 584,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '16.24530644'},
#   {'dateRep': '24/05/2020',
#    'day': '24',
#    'month': '05',
#    'year': '2020',
#    'cases': 782,
#    'deaths': 11,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '15.68013801'},
#   {'dateRep': '23/05/2020',
#    'day': '23',
#    'month': '05',
#    'year': '2020',
#    'cases': 540,
#    'deaths': 12,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '14.29481819'},
#   {'dateRep': '22/05/2020',
#    'day': '22',
#    'month': '05',
#    'year': '2020',
#    'cases': 531,
#    'deaths': 6,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '13.44049382'},
#   {'dateRep': '21/05/2020',
#    'day': '21',
#    'month': '05',
#    'year': '2020',
#    'cases': 492,
#    'deaths': 9,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '12.49416529'},
#   {'dateRep': '20/05/2020',
#    'day': '20',
#    'month': '05',
#    'year': '2020',
#    'cases': 581,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '11.64246962'},
#   {'dateRep': '19/05/2020',
#    'day': '19',
#    'month': '05',
#    'year': '2020',
#    'cases': 408,
#    'deaths': 4,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.98266833'},
#   {'dateRep': '18/05/2020',
#    'day': '18',
#    'month': '05',
#    'year': '2020',
#    'cases': 262,
#    'deaths': 1,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.40961384'},
#   {'dateRep': '17/05/2020',
#    'day': '17',
#    'month': '05',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.3386392'},
#   {'dateRep': '16/05/2020',
#    'day': '16',
#    'month': '05',
#    'year': '2020',
#    'cases': 1063,
#    'deaths': 32,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '10.6908837'},
#   {'dateRep': '15/05/2020',
#    'day': '15',
#    'month': '05',
#    'year': '2020',
#    'cases': 113,
#    'deaths': 6,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '8.32769107'},
#   {'dateRep': '14/05/2020',
#    'day': '14',
#    'month': '05',
#    'year': '2020',
#    'cases': 259,
#    'deaths': 3,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '8.61421832'},
#   {'dateRep': '13/05/2020',
#    'day': '13',
#    'month': '05',
#    'year': '2020',
#    'cases': 280,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '8.25408774'},
#   {'dateRep': '12/05/2020',
#    'day': '12',
#    'month': '05',
#    'year': '2020',
#    'cases': 285,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '7.84401204'},
#   {'dateRep': '11/05/2020',
#    'day': '11',
#    'month': '05',
#    'year': '2020',
#    'cases': 369,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '7.54697003'},
#   {'dateRep': '10/05/2020',
#    'day': '10',
#    'month': '05',
#    'year': '2020',
#    'cases': 255,
#    'deaths': 6,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '6.75573423'},
#   {'dateRep': '09/05/2020',
#    'day': '09',
#    'month': '05',
#    'year': '2020',
#    'cases': 215,
#    'deaths': 3,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '6.37983151'},
#   {'dateRep': '08/05/2020',
#    'day': '08',
#    'month': '05',
#    'year': '2020',
#    'cases': 171,
#    'deaths': 2,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '5.99867141'},
#   {'dateRep': '07/05/2020',
#    'day': '07',
#    'month': '05',
#    'year': '2020',
#    'cases': 168,
#    'deaths': 9,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
#    'popData2019': 38041757,
#    'continentExp': 'Asia',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '5.82517784'},
#   {'dateRep': '06/05/2020',
#    'day': '06',
#    'month': '05',
#    'year': '2020',
#    'cases': 330,
#    'deaths': 5,
#    'countriesAndTerritories': 'Afghanistan',
#    'geoId': 'AF',
#    'countryterritoryCode': 'AFG',
# ...
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.30399403'},
#   {'dateRep': '04/08/2020',
#    'day': '04',
#    'month': '08',
#    'year': '2020',
#    'cases': 16,
#    'deaths': 2,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.30399403'},
#   {'dateRep': '03/08/2020',
#    'day': '03',
#    'month': '08',
#    'year': '2020',
#    'cases': 34,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.39197435'},
#   {'dateRep': '02/08/2020',
#    'day': '02',
#    'month': '08',
#    'year': '2020',
#    'cases': 5,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.34169988'},
#   {'dateRep': '01/08/2020',
#    'day': '01',
#    'month': '08',
#    'year': '2020',
#    'cases': 31,
#    'deaths': 3,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.47995467'},
#   {'dateRep': '31/07/2020',
#    'day': '31',
#    'month': '07',
#    'year': '2020',
#    'cases': 78,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.47995467'},
#   {'dateRep': '30/07/2020',
#    'day': '30',
#    'month': '07',
#    'year': '2020',
#    'cases': 50,
#    'deaths': 6,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.33227342'},
#   {'dateRep': '29/07/2020',
#    'day': '29',
#    'month': '07',
#    'year': '2020',
#    'cases': 18,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.33541558'},
#   {'dateRep': '28/07/2020',
#    'day': '28',
#    'month': '07',
#    'year': '2020',
#    'cases': 2,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.33855773'},
#   {'dateRep': '27/07/2020',
#    'day': '27',
#    'month': '07',
#    'year': '2020',
#    'cases': 50,
#    'deaths': 5,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.33227342'},
#   {'dateRep': '26/07/2020',
#    'day': '26',
#    'month': '07',
#    'year': '2020',
#    'cases': 29,
#    'deaths': 2,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.24743526'},
#   {'dateRep': '25/07/2020',
#    'day': '25',
#    'month': '07',
#    'year': '2020',
#    'cases': 39,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.23486664'},
#   {'dateRep': '24/07/2020',
#    'day': '24',
#    'month': '07',
#    'year': '2020',
#    'cases': 33,
#    'deaths': 3,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.30713619'},
#   {'dateRep': '23/07/2020',
#    'day': '23',
#    'month': '07',
#    'year': '2020',
#    'cases': 30,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.23486664'},
#   {'dateRep': '22/07/2020',
#    'day': '22',
#    'month': '07',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.2442931'},
#   {'dateRep': '21/07/2020',
#    'day': '21',
#    'month': '07',
#    'year': '2020',
#    'cases': 44,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.2442931'},
#   {'dateRep': '20/07/2020',
#    'day': '20',
#    'month': '07',
#    'year': '2020',
#    'cases': 18,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.12803339'},
#   {'dateRep': '19/07/2020',
#    'day': '19',
#    'month': '07',
#    'year': '2020',
#    'cases': 49,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '1.07147462'},
#   {'dateRep': '18/07/2020',
#    'day': '18',
#    'month': '07',
#    'year': '2020',
#    'cases': 31,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.97406783'},
#   {'dateRep': '17/07/2020',
#    'day': '17',
#    'month': '07',
#    'year': '2020',
#    'cases': 31,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.91750905'},
#   {'dateRep': '16/07/2020',
#    'day': '16',
#    'month': '07',
#    'year': '2020',
#    'cases': 51,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.89551397'},
#   {'dateRep': '15/07/2020',
#    'day': '15',
#    'month': '07',
#    'year': '2020',
#    'cases': 19,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.75725919'},
#   {'dateRep': '14/07/2020',
#    'day': '14',
#    'month': '07',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.72269549'},
#   {'dateRep': '13/07/2020',
#    'day': '13',
#    'month': '07',
#    'year': '2020',
#    'cases': 23,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.75097488'},
#   {'dateRep': '12/07/2020',
#    'day': '12',
#    'month': '07',
#    'year': '2020',
#    'cases': 25,
#    'deaths': 2,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.75097488'},
#   {'dateRep': '11/07/2020',
#    'day': '11',
#    'month': '07',
#    'year': '2020',
#    'cases': 62,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.77296996'},
#   {'dateRep': '10/07/2020',
#    'day': '10',
#    'month': '07',
#    'year': '2020',
#    'cases': 10,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.62528871'},
#   {'dateRep': '09/07/2020',
#    'day': '09',
#    'month': '07',
#    'year': '2020',
#    'cases': 33,
#    'deaths': 2,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.6190044'},
#   {'dateRep': '08/07/2020',
#    'day': '08',
#    'month': '07',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.52473977'},
#   {'dateRep': '07/07/2020',
#    'day': '07',
#    'month': '07',
#    'year': '2020',
#    'cases': 7,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.53416623'},
#   {'dateRep': '06/07/2020',
#    'day': '06',
#    'month': '07',
#    'year': '2020',
#    'cases': 0,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.53416623'},
#   {'dateRep': '05/07/2020',
#    'day': '05',
#    'month': '07',
#    'year': '2020',
#    'cases': 18,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.54673485'},
#   {'dateRep': '04/07/2020',
#    'day': '04',
#    'month': '07',
#    'year': '2020',
#    'cases': 13,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.509029'},
#   {'dateRep': '03/07/2020',
#    'day': '03',
#    'month': '07',
#    'year': '2020',
#    'cases': 24,
#    'deaths': 2,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.50274469'},
#   {'dateRep': '02/07/2020',
#    'day': '02',
#    'month': '07',
#    'year': '2020',
#    'cases': 7,
#    'deaths': 2,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.42733298'},
#   {'dateRep': '01/07/2020',
#    'day': '01',
#    'month': '07',
#    'year': '2020',
#    'cases': 8,
#    'deaths': 2,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.44618591'},
#   {'dateRep': '30/06/2020',
#    'day': '30',
#    'month': '06',
#    'year': '2020',
#    'cases': 9,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.42104868'},
#   {'dateRep': '29/06/2020',
#    'day': '29',
#    'month': '06',
#    'year': '2020',
#    'cases': 23,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.3990536'},
#   {'dateRep': '28/06/2020',
#    'day': '28',
#    'month': '06',
#    'year': '2020',
#    'cases': 32,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.33306836'},
#   {'dateRep': '27/06/2020',
#    'day': '27',
#    'month': '06',
#    'year': '2020',
#    'cases': 15,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.25765665'},
#   {'dateRep': '26/06/2020',
#    'day': '26',
#    'month': '06',
#    'year': '2020',
#    'cases': 8,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.24823019'},
#   {'dateRep': '25/06/2020',
#    'day': '25',
#    'month': '06',
#    'year': '2020',
#    'cases': 3,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.23880373'},
#   {'dateRep': '24/06/2020',
#    'day': '24',
#    'month': '06',
#    'year': '2020',
#    'cases': 3,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.28279389'},
#   {'dateRep': '23/06/2020',
#    'day': '23',
#    'month': '06',
#    'year': '2020',
#    'cases': 7,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.28593604'},
#   {'dateRep': '22/06/2020',
#    'day': '22',
#    'month': '06',
#    'year': '2020',
#    'cases': 4,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.26708312'},
#   {'dateRep': '21/06/2020',
#    'day': '21',
#    'month': '06',
#    'year': '2020',
#    'cases': 6,
#    'deaths': 0,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.27022527'},
#   {'dateRep': '20/06/2020',
#    'day': '20',
#    'month': '06',
#    'year': '2020',
#    'cases': 11,
#    'deaths': 1,
#    'countriesAndTerritories': 'Angola',
#    'geoId': 'AO',
#    'countryterritoryCode': 'AGO',
#    'popData2019': 31825299,
#    'continentExp': 'Africa',
#    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '0.25137234'},
#   ...]}

# %%
covid_data.keys
# Out:
# <function dict.keys>

# %% [markdown]
# **Q4:** If **you** were writing the testing `assert` statements that made sure that `covid_data` contained the in-memory data structure and that your answers to **A**, **B**, and **C** of **Q3** were correct, you would have three lines that checked
#
# 1. the Python data type of the top level,
# 2. the Python data type of the child mapping from the root top level to its value, and
# 3. the Python data type of an element (probably the first) in the elements within the structure asserted by the previous step.
#
# All three of these would take the form of:
# ```
#     assert isinstance(<expression>, <expected data type>)
# ```
# Note that your answers in **Q2** were in terms of the JSON data types, and these asserts are in terms of Python data types.
#
# Make these three assertions in the cell that follows.

# %%
assert isinstance(covid_data,dict)
assert isinstance(covid_data['records'],list)
assert isinstance(covid_data['records'][0],dict)

# %% [markdown]
# **Q5:** Hopefully, you have determined that the top level of the in-memory data structure is a dictionary, that there is only one child mapping, with  maps the string `"records"` to a list, and that the elements of this list are each a dictionary.
#
# One last sanity check you should perform before writing code to traverse the structure:
#
# - because the file is large, it is difficult to be sure that there is **only** one child mapping in the top level dictionary.  So in the cell that follows, just print the set of dictionary **keys** found in the top level dictionary (converted to a list).   If there is only one element in the list, then we are ready to start building a tabular structure from this tree.

# %%
assert len(list(covid_data.keys()))==1

# %% [markdown]
# **Q6:** If our goal is one or more `pandas` DataFrame tables of **tidy** data, there are a number of possible solution paths we could pursue.  For now, we are going to assume we want **all** of the innermost dictionary fields as the columns in a `pandas` DataFrame result and will perform normalization _after_ we get this single table.
#
# Given the innermost structure, representing the **rows** of our desired DataFrame is a **dictionary**, one path would be for us to build a **List of Dictionaries** data structure by starting with an empty list and then appending a **copy** of each of the dictionaries within the `covid_data['records']` list.
#
# In the cell that follows, write this loop and build a structure named `LoD`.

# %%
LoD=[]
for dic in covid_data['records']:
    LoD.append(dic)

# Display a subset of the LoD
for key,value in LoD[0].items():
    print("{0:>60} {1:>15}".format(key, value))
# Out:
#                                                      dateRep      21/09/2020
#                                                          day              21
#                                                        month              09
#                                                         year            2020
#                                                        cases               0
#                                                       deaths               0
#                                      countriesAndTerritories     Afghanistan
#                                                        geoId              AF
#                                         countryterritoryCode             AFG
#                                                  popData2019        38041757
#                                                 continentExp            Asia
#   Cumulative_number_for_14_days_of_COVID-19_cases_per_100000      1.69813397

# %%
# Testing cell
assert isinstance(LoD, list)
assert len(LoD) == 44136
assert isinstance(LoD[0], dict)

# %% [markdown]
# **Q7:** With the successfully created `LoD`, create a pandas DataFrame named `covid_df`.

# %%
covid_df=pd.DataFrame(LoD)

# Display a subset of the data frame
covid_df.head()
# Out:
#       dateRep day month  year  cases  deaths countriesAndTerritories geoId  \
# 0  21/09/2020  21    09  2020      0       0             Afghanistan    AF
# 1  20/09/2020  20    09  2020    125       4             Afghanistan    AF
# 2  19/09/2020  19    09  2020     47       1             Afghanistan    AF
# 3  18/09/2020  18    09  2020      0       0             Afghanistan    AF
# 4  17/09/2020  17    09  2020     17       0             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#   Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                         1.69813397
# 1                                         1.89265706
# 2                                         1.61664457
# 3                                         1.53515517
# 4                                         1.65344624

# %%
# Testing cell
assert covid_df.shape == (44136, 12)

# %% [markdown]
# > You've reached the second checkpoint in the lab.  Make sure to have it signed off by the instructor or TA.
# >
# > Checkpoint 2: The data frame `covid_df` is not tidy.  What are two reasons it's not tidy, and how would you fix these issues?  (Note: you don't have to actually fix them, just make a plan.)

# %% [markdown]
# ---
#
# **Q8:** Find the number of unique countries, assigning to `ncountry`

# %%
ncountry=covid_df.countryterritoryCode.nunique()

# Display the result
print(ncountry)
# Out:
# 209

# %% [markdown]
# **Q9:** Use a GroupBy to group by `"countryterritoryCode"` and then aggregate, computing the `max` and `mean` for the columns `cases` and `deaths`.  Name the resultant dataframe `covid_df_agg`.

# %%
covid_groupby=covid_df.groupby('countryterritoryCode')
agg={'cases':['max','mean'],
     'deaths':['max','mean'],}
covid_df_agg=covid_groupby.agg(agg)

# Display the aggregated data frame
covid_df_agg
# Out:
#                       cases              deaths
#                         max         mean    max       mean
# countryterritoryCode
# ABW                     176    19.404372      2   0.125683
# AFG                    1063   152.515625     56   5.628906
# AGO                     180    21.690217      8   0.826087
# AIA                       2     0.016760      0   0.000000
# ALB                     178    62.868020      6   1.837563
# ...                     ...          ...    ...        ...
# XKX                     496    78.453125     40   3.192708
# YEM                     116    12.303030     52   3.551515
# ZAF                   13944  3339.449495    572  80.570707
# ZMB                     527    75.566845     40   1.764706
# ZWE                     490    41.529730     18   1.216216
#
# [209 rows x 4 columns]

# %% [markdown]
# > You've reached the third (and final) checkpoint in the lab.  Make sure to have it signed off by the instructor or TA.
# >
# > Checkpoint 3: Use `covid_df_agg` to answer the following questions:
# >
# > - For the timeframe represented by this dataset, which country had the highest maximum death count?
# > - For the timeframe represented by this dataset, of the countries with a maximum of at least 10 deaths, which country had the lowest mean case count?

# %%
a=covid_df_agg[('deaths','max')].max()
covid_df_agg[covid_df_agg[('deaths','max')]==a]
# Out:
#                       cases               deaths
#                         max          mean    max        mean
# countryterritoryCode
# USA                   78427  25582.007519   4928  750.033835

# %%
ten_more=covid_df_agg[covid_df_agg[('deaths','max')]>=10]    
b=ten_more[("cases","mean")].min()
ten_more[ten_more[('cases','mean')]==b]
# Out:
#                      cases           deaths
#                        max      mean    max      mean
# countryterritoryCode
# TCD                     83  6.188172     10  0.435484

# %% [markdown]
# ---
#
# ---
# ## Part C
#
# How much time (in minutes/hours) did you spend on this lab outside of class?

# %% [markdown]
# YOUR ANSWER HERE
